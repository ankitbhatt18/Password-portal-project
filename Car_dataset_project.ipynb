# %%
import pandas as pd

# %%
df=pd.read_csv("car_data.csv")
df.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
df.shape
# Out:
# (428, 15)

# %% [markdown]
# ### Q. 1) Instruction ( For Data Cleaning ) - Find all Null Values in the dataset. If there is any null value in any column, then fill it with the mean of that column??

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df["Cylinders"].fillna(df["Cylinders"].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# Now we have done the fillna part......

# %% [markdown]
# # ---------------------------------------------------------------------------------

# %% [markdown]
# First of all, we have to replace categorical data to (NaN to mode):

# %%
df.mode()
# Out:
#       Make     Model   Type Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 0   Toyota  C240 4dr  Sedan   Asia      Front  $13,270   $14,207          3.0
# 1      NaN  C320 4dr    NaN    NaN        NaN  $15,389   $19,638          NaN
# 2      NaN   G35 4dr    NaN    NaN        NaN  $19,635   $68,306          NaN
# 3      NaN       NaN    NaN    NaN        NaN  $19,860        NaN         NaN
# 4      NaN       NaN    NaN    NaN        NaN  $21,055        NaN         NaN
# 5      NaN       NaN    NaN    NaN        NaN  $21,595        NaN         NaN
# 6      NaN       NaN    NaN    NaN        NaN  $23,495        NaN         NaN
# 7      NaN       NaN    NaN    NaN        NaN  $23,895        NaN         NaN
# 8      NaN       NaN    NaN    NaN        NaN  $25,700        NaN         NaN
# 9      NaN       NaN    NaN    NaN        NaN  $27,490        NaN         NaN
# 10     NaN       NaN    NaN    NaN        NaN  $28,495        NaN         NaN
# ...

# %%
data=df.fillna({"Make":"Toyota","Model":"MDX","Type":"Sedan","Origin":"Asia","DriveTrain":"Front"})

# %%
data.head(31)
# Out:
#       Make                             Model    Type  Origin DriveTrain  \
# 0    Acura                               MDX     SUV    Asia        All
# 1    Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2    Acura                           TSX 4dr   Sedan    Asia      Front
# 3    Acura                            TL 4dr   Sedan    Asia      Front
# 4    Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5    Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6    Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7     Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8     Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9     Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10    Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11    Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# ...

# %% [markdown]
# Now we have MSRP and Invoice , which is in string because of dollar sign , so we have to deal with it and making int by removing the dollar sign and substituting th NaN values to the mean.....and now we have to move with the "Data" data frame:

# %%
data

# %%
df=df.fillna({"EngineSize":df["EngineSize"].mean(),"Cylinders":df["Cylinders"].mean(),
                  "Horsepower":df["Horsepower"].mean(),"MPG_City":df["MPG_City"].mean(),"Weight":df["Weight"].mean(),
                 "Wheelbase":df["Wheelbase"].mean(),"Length":df["Length"].mean(),"MPG_Highway":df["MPG_Highway"].mean()})

# %%
df.head(31)
# Out:
#      Make                             Model    Type  Origin DriveTrain  \
# 0   Acura                               MDX     SUV    Asia        All
# 1   Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2   Acura                           TSX 4dr   Sedan    Asia      Front
# 3   Acura                            TL 4dr   Sedan    Asia      Front
# 4   Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5   Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6   Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7    Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8    Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9    Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10   Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11   Audi           A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# ...

# %% [markdown]
# # --------------------------------------------------------------------------

# %% [markdown]
# ### Q. 2) Question ( Based on Value Counts )- Check what are the different types of Make are there in our dataset. And, what is the count (occurrence) of each Make in the data ?

# %%
df["Make"].unique()
# Out:
# array(['Acura', 'Audi', 'BMW', 'Buick', 'Cadillac', 'Chevrolet',
#        'Chrysler', 'Dodge', 'Ford', 'GMC', 'Honda', 'Hummer', 'Hyundai',
#        'Infiniti', 'Isuzu', 'Jaguar', 'Jeep', 'Kia', 'Land Rover',
#        'Lexus', 'Lincoln', 'MINI', 'Mazda', 'Mercedes-Benz', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Oldsmobile', 'Pontiac', 'Porsche', 'Saab',
#        'Saturn', 'Scion', 'Subaru', 'Suzuki', 'Toyota', 'Volkswagen',
#        'Volvo'], dtype=object)

# %%
df["Make"].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Chrysler         15
# Volkswagen       15
# Mitsubishi       13
# Dodge            13
# Jaguar           12
# Hyundai          12
# Volvo            12
# Pontiac          11
# Lexus            11
# Mazda            11
# Subaru           11
# Kia              11
# Mercury           9
# Lincoln           9
# Buick             9
# Suzuki            8
# GMC               8
# Cadillac          8
# Saturn            8
# Infiniti          8
# Porsche           7
# Acura             7
# Saab              7
# Jeep              3
# Land Rover        3
# Oldsmobile        3
# Isuzu             2
# MINI              2
# Scion             2
# Hummer            1
# Name: Make, dtype: int64

# %% [markdown]
# ### Q. 3) Instruction ( Filtering ) - Show all the records where Origin is Asia or Europe.?

# %%
'''1st Method:'''
df[(df["Origin"]=="Asia")|(df["Origin"]=="Europe")]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
'''2nd Method::'''
df[df["Origin"].isin(["Asia","Europe"])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### Q. 4) Instruction ( Removing unwanted records ) - Remove all the records (rows) where Weight is above 4000.?

# %%
df[~(df["Weight"]>4000)] 
## This means that we have to delete the data which has weight greter than 4000, so we use simply "~" operator (negate..)
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### Q. 5) Instruction ( Applying function on a column ) - Increase all the values of 'MPG_City' column by 3.

# %%
df["MPG_City"]=df["MPG_City"].apply(lambda x: x+3)

# %%
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# # Project Completed-----------------------------
